# %% [markdown]
# ## the prurpose of this code is to check some columns for removing it before working on the silver layer

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("DataCoSupplyChainDataset.csv",encoding='latin1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8002 entries, 0 to 8001
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Type                           8002 non-null   object
#  1   Days for shipping (real)       8002 non-null   int64
#  2   Days for shipment (scheduled)  8002 non-null   int64
#  3   Benefit per order              8002 non-null   float64
#  4   Sales per customer             8002 non-null   float64
#  5   Delivery Status                8002 non-null   object
#  6   Late_delivery_risk             8002 non-null   int64
#  7   Category Id                    8002 non-null   int64
#  8   Category Name                  8002 non-null   object
#  9   Customer City                  8002 non-null   object
#  10  Customer Country               8002 non-null   object
#  11  Customer Email                 8002 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Type                                0
# Days for shipping (real)            0
# Days for shipment (scheduled)       0
# Benefit per order                   0
# Sales per customer                  0
# Delivery Status                     0
# Late_delivery_risk                  0
# Category Id                         0
# Category Name                       0
# Customer City                       0
# Customer Country                    0
# Customer Email                      0
# Customer Fname                      0
# Customer Id                         0
# Customer Lname                      0
# Customer Password                   0
# Customer Segment                    0
# Customer State                      0
# Customer Street                     0
# Customer Zipcode                    0
# Department Id                       0
# Department Name                     0
# Latitude                            0
# Longitude                           0
# Market                              0
# ...

# %% [markdown]
# ## Here we Found Order Zipcode column have many Nulls that makes this column mendatory to be removed

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7997    False
# 7998    False
# 7999    False
# 8000    False
# 8001    False
# Length: 8002, dtype: bool

# %% [markdown]
# ## continue our work on silver layer

# %% [markdown]
# -- Categorical columns to inspect ( focused on text-based for quality checks)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("silver_post_step1.csv",encoding='latin1')
df.head()
# Out:
#    order_item_id  order_id  sales_per_item  item_profit  item_profit_ratio  \
# 0         180519     77204           34.98         9.79               0.28
# 1         180518     77203           10.91         1.53               0.14
# 2         180517     77202          314.64        91.25               0.29
# 3         180516     77201          172.66      -126.56              -0.73
# 4         180515     77200          161.87      -107.96              -0.67
#
#    sales_per_customer  order_item_discount  order_item_discount_rate  \
# 0               34.98                 4.77                      0.12
# 1               10.91                 0.63                      0.06
# 2              314.64                13.11                      0.04
# 3              172.66                43.16                      0.20
# 4              161.87                53.96                      0.25
#
#    order_item_quantity  product_price  ... order_country    order_region  \
# ...

# %%
df.columns
# Out:
# Index(['order_item_id', 'order_id', 'sales_per_item', 'item_profit',
#        'item_profit_ratio', 'sales_per_customer', 'order_item_discount',
#        'order_item_discount_rate', 'order_item_quantity', 'product_price',
#        'shipping_date', 'actual_shipping_days', 'scheduled_shipping_days',
#        'delivery_status', 'late_delivery_risk', 'shipping_mode', 'order_date',
#        'order_status', 'payment_type', 'customer_id', 'customer_segment',
#        'product_card_id', 'product_name', 'product_category_name',
#        'product_department_name', 'product_category_id', 'department_id',
#        'order_city', 'order_state', 'order_country', 'order_region', 'market',
#        'customer_city', 'customer_state', 'customer_country', 'latitude',
#        'longitude', 'dwh_delivery_variance_days', 'dwh_create_date'],
#       dtype='object')

# %%
categorical_columns = [
    'delivery_status',
    'shipping_mode',
    'order_status',
    'payment_type',
    'customer_segment',
    'product_category_name',
    'product_department_name',
    'order_city',
    'order_country',
    'order_state',
    'order_region',
    'market',
    'customer_city',
    'customer_state',
    'customer_country'
]

for col in categorical_columns:
    print(f"Unique values for {col}: {df[col].unique()}")
    print("--------------------------------------------------")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('delivery_status', 'shipping_mode', 'order_status', 'payment_type', 'customer_segment', 'product_category_name', 'product_department_name', 'order_city', 'order_country', 'order_state', 'order_region', 'market', 'customer_city', 'customer_state', 'customer_country')
#
# ...

# %%
categorical_columns = [
    'delivery_status',
    'shipping_mode',
    'order_status',
    'payment_type',
    'customer_segment',
    'product_category_name',
    'product_department_name',
    'order_city',
    'order_country',

    'order_region',
    'market',

    'customer_state',
    'customer_country'
]

for col in categorical_columns:
    print(f"Unique values for {col}: {df[col].unique()}")
    print("--------------------------------------------------")
# Out:
# Unique values for delivery_status: ['Late delivery' 'Shipping on time' 'Advance shipping' 'Shipping canceled']
# --------------------------------------------------
# Unique values for shipping_mode: ['Same Day' 'Standard Class' 'First Class' 'Second Class']
# --------------------------------------------------
# Unique values for order_status: ['CLOSED' 'PENDING_PAYMENT' 'COMPLETE' 'PROCESSING' 'PENDING'
#  'SUSPECTED_FRAUD' 'ON_HOLD' 'PAYMENT_REVIEW' 'CANCELED']
# --------------------------------------------------
# Unique values for payment_type: ['CASH' 'PAYMENT' 'DEBIT' 'TRANSFER']
# --------------------------------------------------
# Unique values for customer_segment: ['Corporate' 'Consumer' 'Home Office']
# --------------------------------------------------
# Unique values for product_category_name: ['Video Games' 'Toys' 'Sporting Goods' "Women's Clothing" 'Pet Supplies'
#  'Music' "Men's Clothing" 'Health and Beauty' 'Garden' 'DVDs' 'Crafts'
# ...

# %% [markdown]
# check order_item_id Duplicates

# %%
df['order_item_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['customer_country'].unique()
# Out:
# array(['EE. UU.', 'Puerto Rico', nan], dtype=object)

# %%
df[df['customer_country'].isna()]
# Out:
#        order_item_id  order_id  sales_per_item  item_profit  \
# 17063         163454     65403          226.76         4.54
#
#        item_profit_ratio  sales_per_customer  order_item_discount  \
# 17063               0.02              226.76                 13.2
#
#        order_item_discount_rate  order_item_quantity  product_price  ...  \
# 17063                      0.06                    4          59.99  ...
#
#       order_country     order_region  market customer_city  customer_state  \
# 17063   Reino Unido  Northern Europe  Europe        Moline              IL
#
#       customer_country latitude longitude dwh_delivery_variance_days  \
# 17063              NaN      NaN       NaN                        NaN
#
#        dwh_create_date
# 17063              NaN
#
# [1 rows x 39 columns]

# %% [markdown]
# ###-- lets move on data post the step 2

# %%
import pandas as pd
import numpy as np

df = pd.read_excel("silver_post_step2.xlsx")

# %%
categorical_columns = [
    'delivery_status',
    'shipping_mode',
    'order_status',
    'payment_type',
    'customer_segment',
    'product_category_name',
    'product_department_name',
    'order_city',
    'order_country',

    'order_region',
    'market',

    'customer_state',
    'customer_country'
]

for col in categorical_columns:
    print(f"Unique values for {col}: {df[col].unique()}")
    print("--------------------------------------------------")
# Out:
# Unique values for delivery_status: ['Late delivery' 'Advance shipping' 'Shipping on time' 'Shipping canceled']
# --------------------------------------------------
# Unique values for shipping_mode: ['Standard Class' 'Same Day' 'First Class' 'Second Class']
# --------------------------------------------------
# Unique values for order_status: ['PENDING' 'PROCESSING' 'CANCELED' 'PENDING_PAYMENT' 'COMPLETE' 'CLOSED'
#  'ON_HOLD' 'PAYMENT_REVIEW']
# --------------------------------------------------
# Unique values for payment_type: ['TRANSFER' 'PAYMENT' 'DEBIT' 'CASH']
# --------------------------------------------------
# Unique values for customer_segment: ['Consumer' 'Corporate' 'Home Office']
# --------------------------------------------------
# Unique values for product_category_name: ["Men's Footwear" 'Cleats' "Women's Apparel" "Girls' Apparel"
#  'Shop By Sport' 'Trade-In' 'Electronics' 'Hunting & Shooting'
#  'Camping & Hiking' 'Fitness Accessories' 'Cardio Equipment'
# ...

# %%
df.isnull().sum()
# Out:
# order_item_id                      0
# order_id                           0
# sales_per_item                     0
# item_profit                        0
# item_profit_ratio                  0
# sales_per_customer                 0
# order_item_discount                0
# order_item_discount_rate           0
# order_item_quantity                0
# product_price                      0
# shipping_date                      0
# actual_shipping_days               0
# scheduled_shipping_days            0
# delivery_status                    0
# late_delivery_risk                 0
# shipping_mode                      0
# order_date                         0
# order_status                       0
# payment_type                       0
# customer_id                        0
# customer_segment                   0
# product_card_id                    0
# product_name                       0
# product_category_name              0
# product_department_name            0
# ...

# %% [markdown]
# ###Now our step3 will be on handling translation and filling the days_varience

# %%
# check order_country count values
df['order_country'].value_counts()
# Out:
# order_country
# Estados Unidos       24267
# Francia              12860
# MΘxico               12855
# Alemania              9337
# Australia             8300
#                      ...
# Guinea Ecuatorial        2
# Kuwait                   2
# Eritrea                  2
# Serbia                   1
# Burundi                  1
# Name: count, Length: 164, dtype: int64

# %%
df[df['delivery_status'] == 'Shipping canceled']
pd.set_option('display.max_columns', None)
#

# %%
df[df['delivery_status'] == 'Shipping canceled']
# Out:
#         order_item_id  order_id  sales_per_item  item_profit  \
# 269            110314     44170           99.58        34.85
# 270            104590     41901           67.18        32.25
# 271            110316     44170           65.58         1.31
# 327            160676     64274          189.98        21.47
# 328             42747     17094          101.98       -68.02
# ...               ...       ...             ...          ...
# 176350          24430      9784          185.99         4.65
# 176351          24411      9778          181.99        85.54
# 176425          23503      9419          173.99        48.72
# 176432          23419      9386          199.99        78.00
# 176433          23418      9386          197.99        87.12
#
#         item_profit_ratio  sales_per_customer  order_item_discount  \
# 269                  0.35               99.58                 20.4
# 270                  0.48               67.18                 12.8
# ...
